# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from pprint import pprint

# %%
# !curl https://api.github.com/users/klv79
# Out:
# {
#   "login": "klv79",
#   "id": 98268944,
#   "node_id": "U_kgDOBdt3EA",
#   "avatar_url": "https://avatars.githubusercontent.com/u/98268944?v=4",
#   "gravatar_id": "",
#   "url": "https://api.github.com/users/klv79",
#   "html_url": "https://github.com/klv79",
#   "followers_url": "https://api.github.com/users/klv79/followers",
#   "following_url": "https://api.github.com/users/klv79/following{/other_user}",
#   "gists_url": "https://api.github.com/users/klv79/gists{/gist_id}",
#   "starred_url": "https://api.github.com/users/klv79/starred{/owner}{/repo}",
#   "subscriptions_url": "https://api.github.com/users/klv79/subscriptions",
#   "organizations_url": "https://api.github.com/users/klv79/orgs",
#   "repos_url": "https://api.github.com/users/klv79/repos",
#   "events_url": "https://api.github.com/users/klv79/events{/privacy}",
#   "received_events_url": "https://api.github.com/users/klv79/received_events",
#   "type": "User",
#   "site_admin": false,
#   "name": null,
# ...

# %%
appid = '98268944'
url = "https://api.github.com/users/klv79"

response = requests.get(f'{url}?uk&appid={appid}')
pprint(response.json())
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/98268944?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2022-01-23T14:13:26Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/klv79/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/klv79/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/klv79/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/klv79/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/klv79',
#  'id': 98268944,
#  'location': None,
#  'login': 'klv79',
#  'name': None,
#  'node_id': 'U_kgDOBdt3EA',
#  'organizations_url': 'https://api.github.com/users/klv79/orgs',
#  'public_gists': 0,
#  'public_repos': 6,
#  'received_events_url': 'https://api.github.com/users/klv79/received_events',
#  'repos_url': 'https://api.github.com/users/klv79/repos',
#  'site_admin': False,
# ...

# %%
url = "https://api.github.com/users/klv79/repos"

# repos = requests.get('https://api.github.com/user/repos', auth=(username, token))
repos = requests.get(f'{url}?uk&appid={appid}')
pprint(repos.json())
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/klv79/hello/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/klv79/hello/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/klv79/hello/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/klv79/hello/branches{/branch}',
#   'clone_url': 'https://github.com/klv79/hello.git',
#   'collaborators_url': 'https://api.github.com/repos/klv79/hello/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/klv79/hello/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/klv79/hello/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/klv79/hello/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/klv79/hello/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/klv79/hello/contributors',
#   'created_at': '2022-01-26T13:41:39Z',
# ...

# %%
for repo in repos.json():
  if not repo['private']:
    print(repo['html_url'])
# Out:
# https://github.com/klv79/hello
# https://github.com/klv79/hello2
# https://github.com/klv79/projekt
# https://github.com/klv79/python
# https://github.com/klv79/python_lesson
# https://github.com/klv79/repo-githab
